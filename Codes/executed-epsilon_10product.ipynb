# %%
import gym
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from agents import OrganicUserEventCounterAgent, organic_user_count_args
from agents import SkylineAgent, skyline_args
from agents import RandomAgent, random_args

from agents import PyTorchMLRAgent, pytorch_mlr_args
from datetime import datetime

# %%
import gym
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from agents import OrganicUserEventCounterAgent, organic_user_count_args
from agents import SkylineAgent, skyline_args
from agents import RandomAgent, random_args
from reco_gym import (
    Configuration,
    build_agent_init,
    env_1_args,
    gather_agent_stats,
    plot_agent_stats
)

from agents import PyTorchMLRAgent, pytorch_mlr_args
from datetime import datetime

# General parameters for experiments
RandomSeed = 42
TrainingDataSamples = [1000, 2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000]
TestingDataSamples = 10000
StatEpochs = 5
StatEpochsNewRandomSeed = True

def grid_search_parameter(
        parameter_name, parameter_values,
        agent_name, agent_pytorch_mlr_args,
        env_args, extra_env_args,
        train_samples=5000, valid_samples=10000, valid_runs=5,
):
    ''' Perform a grid search by doing an A/B test with model variants that use different parameter values, log the rsult and return the optimal parameter value '''
    print(f'\tGrid search for {agent_name}')
    grid_search_agent_inits = dict()
    for parameter_value in parameter_values:
        agent_name_with_specified_parameter = f'{agent_name} ({parameter_name} = {parameter_value})'
        grid_search_agent_inits.update(
            build_agent_init(
                agent_name_with_specified_parameter,
                PyTorchMLRAgent,
                {
                    **agent_pytorch_mlr_args,
                    parameter_name: parameter_value
                }
            )
        )

    ### Run A/B test with model variants
    agent_stats = gather_agent_stats(
        env,
        env_args,
        {
            **extra_env_args
        },
        grid_search_agent_inits,
        [train_samples],
        valid_samples,
        valid_runs,
        StatEpochsNewRandomSeed
    )

    # Messy way to get everything into pandas, but it works 
    gg = agent_stats[list(agent_stats.keys())[1]]
    l = []
    for k in list(gg.keys()):
        f = pd.DataFrame(gg[k])
        f['Alg'] = k
        f['Samples'] = agent_stats[list(agent_stats.keys())[0]]
        l.append(f)
    agent_stats_df = pd.concat(l)
    agent_stats_df.columns = [str(c) for c in agent_stats_df.columns]
    values = agent_stats_df['AgentStats.Q0_500'].values
    optimal_parameter_value = parameter_values[np.argmax(values)]
    print(agent_stats_df)
    agent_stats_df.to_csv(f'GS_{agent_name.replace(" ", "_")}_pop.csv', index=False)
    print(f'\t... optimal {parameter_name} = {optimal_parameter_value}!')
    return optimal_parameter_value

num_products=10
print('#' * 48)
print(f'{datetime.now()}\tLogging Popularity with {num_products} products...')
print('#' * 48)

    # Environment parameters
std_env_args = {
    **env_1_args,
    'random_seed': RandomSeed,
    'num_products': num_products,
}
env = gym.make('reco-gym-v1')

logging_epsilon = 0.01
# Logging policy
logger = OrganicUserEventCounterAgent(Configuration({
    **organic_user_count_args,
    **std_env_args,
    'select_randomly': True,
    'epsilon': logging_epsilon
}))

std_extra_env_args = {
    'num_products': num_products,
    'number_of_flips': num_products // 2,
    'agent': logger,
}

    ###################################################
    # Grid searches for POEM and Dual Bandit variants #
    ###################################################
# Out:
# ################################################
# 2022-02-26 04:32:06.851435	Logging Popularity with 10 products...
# ################################################

# %%
 # Original POEM
lambdas_poem_no_log = [.0, .05, .1, .25, .5, 1.0, 2.0]
poem_no_log_mlr_args = {
    **pytorch_mlr_args,
    'logIPS': False,    }
optimal_svp_strength_nolog = grid_search_parameter(
    'variance_penalisation_strength', lambdas_poem_no_log,
    'POEM no log', poem_no_log_mlr_args,
    std_env_args, std_extra_env_args,
)
# Out:
# 	Grid search for POEM no log
# Agent: POEM no log (variance_penalisation_strength = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (477.5106854438782s)
# Agent: POEM no log (variance_penalisation_strength = 0.05)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (489.0848636627197s)
# Agent: POEM no log (variance_penalisation_strength = 0.1)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (467.89471197128296s)
# Agent: POEM no log (variance_penalisation_strength = 0.25)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (458.5068826675415s)
# Agent: POEM no log (variance_penalisation_strength = 0.5)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (505.1076967716217s)
# Agent: POEM no log (variance_penalisation_strength = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (503.48791670799255s)
# Agent: POEM no log (variance_penalisation_strength = 2.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (461.02576184272766s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.014891           0.015011           0.015132
# 0           0.013005           0.013118           0.013231
# 0           0.015491           0.015614           0.015737
# 0           0.013870           0.013986           0.014102
# 0           0.014075           0.014192           0.014310
# 0           0.014037           0.014154           0.014271
# 0           0.013660           0.013776           0.013891
#
#                                                  Alg  Samples
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 	... optimal variance_penalisation_strength = 0.1!

# %%
optimal_svp_strength_nolog
# Out:
# 0.1

# %%
# Logarithmic POEM
lambdas_poem_log = [0.0, .05, .1, .25, .5, 1.0, 2.0]
poem_log_mlr_args = {
    **pytorch_mlr_args,
    'logIPS': True,
}
optimal_svp_strength_withlog = grid_search_parameter(
    'variance_penalisation_strength', lambdas_poem_log,
    'POEM log', poem_log_mlr_args,
    std_env_args, std_extra_env_args,
)
# Out:
# 	Grid search for POEM log
# Agent: POEM log (variance_penalisation_strength = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (438.88025522232056s)
# Agent: POEM log (variance_penalisation_strength = 0.05)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (456.63827562332153s)
# Agent: POEM log (variance_penalisation_strength = 0.1)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (433.3420612812042s)
# Agent: POEM log (variance_penalisation_strength = 0.25)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (479.1481463909149s)
# Agent: POEM log (variance_penalisation_strength = 0.5)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (442.65211033821106s)
# Agent: POEM log (variance_penalisation_strength = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (433.1237895488739s)
# Agent: POEM log (variance_penalisation_strength = 2.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (440.05778765678406s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.013598           0.013713           0.013828
# 0           0.013601           0.013716           0.013832
# 0           0.013610           0.013725           0.013840
# 0           0.013602           0.013717           0.013832
# 0           0.013639           0.013754           0.013869
# 0           0.013667           0.013782           0.013898
# 0           0.013748           0.013863           0.013979
#
#                                                 Alg  Samples
# 0   POEM log (variance_penalisation_strength = 0.0)     5000
# 0  POEM log (variance_penalisation_strength = 0.05)     5000
# 0   POEM log (variance_penalisation_strength = 0.1)     5000
# 0  POEM log (variance_penalisation_strength = 0.25)     5000
# 0   POEM log (variance_penalisation_strength = 0.5)     5000
# 0   POEM log (variance_penalisation_strength = 1.0)     5000
# 0   POEM log (variance_penalisation_strength = 2.0)     5000
# 	... optimal variance_penalisation_strength = 2.0!

# %%
optimal_svp_strength_withlog
# Out:
# 2.0

# %%
# Dual Bandit
alphas_dual_bandit_no_log = [.0, .80, .85, .90, .925, .95, .975, .99, .999, .9999, 1.0]
dual_bandit_no_log_mlr_args = {
    **pytorch_mlr_args,
    'logIPS': False,
    'll_IPS': False,
}
optimal_ll_strength_nolog = grid_search_parameter(
    'alpha', alphas_dual_bandit_no_log,
    'Dual Bandit no log', dual_bandit_no_log_mlr_args,
    std_env_args, std_extra_env_args,
)
# Out:
# 	Grid search for Dual Bandit no log
# Agent: Dual Bandit no log (alpha = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (412.51013469696045s)
# Agent: Dual Bandit no log (alpha = 0.8)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (644.3047666549683s)
# Agent: Dual Bandit no log (alpha = 0.85)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (623.2408604621887s)
# Agent: Dual Bandit no log (alpha = 0.9)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (598.5255599021912s)
# Agent: Dual Bandit no log (alpha = 0.925)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (586.5096814632416s)
# Agent: Dual Bandit no log (alpha = 0.95)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (589.9801592826843s)
# Agent: Dual Bandit no log (alpha = 0.975)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (562.5434153079987s)
# Agent: Dual Bandit no log (alpha = 0.99)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (474.9770653247833s)
# Agent: Dual Bandit no log (alpha = 0.999)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (474.4936647415161s)
# Agent: Dual Bandit no log (alpha = 0.9999)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (515.4275891780853s)
# Agent: Dual Bandit no log (alpha = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (467.5966672897339s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.014353           0.014471           0.014590
# 0           0.013193           0.013306           0.013419
# 0           0.013603           0.013718           0.013834
# 0           0.013919           0.014035           0.014152
# 0           0.013531           0.013646           0.013761
# 0           0.013443           0.013557           0.013672
# 0           0.013788           0.013903           0.014019
# 0           0.013282           0.013396           0.013510
# 0           0.014679           0.014798           0.014918
# 0           0.015674           0.015797           0.015921
# 0           0.015691           0.015814           0.015938
#
#                                    Alg  Samples
# 0     Dual Bandit no log (alpha = 0.0)     5000
# 0     Dual Bandit no log (alpha = 0.8)     5000
# 0    Dual Bandit no log (alpha = 0.85)     5000
# 0     Dual Bandit no log (alpha = 0.9)     5000
# 0   Dual Bandit no log (alpha = 0.925)     5000
# 0    Dual Bandit no log (alpha = 0.95)     5000
# 0   Dual Bandit no log (alpha = 0.975)     5000
# 0    Dual Bandit no log (alpha = 0.99)     5000
# 0   Dual Bandit no log (alpha = 0.999)     5000
# 0  Dual Bandit no log (alpha = 0.9999)     5000
# 0     Dual Bandit no log (alpha = 1.0)     5000
# 	... optimal alpha = 1.0!

# %%
optimal_ll_strength_nolog
# Out:
# 0.0

# %%
# Logarithmic Dual Bandit
alphas_dual_bandit_log = [.0, .80, .85, .90, .925, .95, .975, .99, .999, .9999, 1.0]
dual_bandit_log_mlr_args = {
    **pytorch_mlr_args,
    'logIPS': True,
    'll_IPS': False,
}
optimal_ll_strength_withlog = grid_search_parameter(
    'alpha', alphas_dual_bandit_log,
    'Dual Bandit log', dual_bandit_log_mlr_args,
    std_env_args, std_extra_env_args,
)
# Out:
# 	Grid search for Dual Bandit log
# Agent: Dual Bandit log (alpha = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (447.7717020511627s)
# Agent: Dual Bandit log (alpha = 0.8)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (485.70972967147827s)
# Agent: Dual Bandit log (alpha = 0.85)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (447.1060793399811s)
# Agent: Dual Bandit log (alpha = 0.9)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (425.6018154621124s)
# Agent: Dual Bandit log (alpha = 0.925)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (444.33236265182495s)
# Agent: Dual Bandit log (alpha = 0.95)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (425.9547584056854s)
# Agent: Dual Bandit log (alpha = 0.975)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (434.06502985954285s)
# Agent: Dual Bandit log (alpha = 0.99)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (465.52231884002686s)
# Agent: Dual Bandit log (alpha = 0.999)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (446.80192160606384s)
# Agent: Dual Bandit log (alpha = 0.9999)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (484.30012249946594s)
# Agent: Dual Bandit log (alpha = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (484.2390134334564s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.013603           0.013718           0.013833
# 0           0.013616           0.013731           0.013847
# 0           0.013726           0.013842           0.013958
# 0           0.013596           0.013711           0.013826
# 0           0.013631           0.013746           0.013862
# 0           0.013743           0.013858           0.013974
# 0           0.013773           0.013889           0.014005
# 0           0.013803           0.013918           0.014035
# 0           0.014335           0.014453           0.014571
# 0           0.015448           0.015571           0.015694
# 0           0.015639           0.015762           0.015886
#
#                                 Alg  Samples
# 0     Dual Bandit log (alpha = 0.0)     5000
# 0     Dual Bandit log (alpha = 0.8)     5000
# 0    Dual Bandit log (alpha = 0.85)     5000
# 0     Dual Bandit log (alpha = 0.9)     5000
# 0   Dual Bandit log (alpha = 0.925)     5000
# 0    Dual Bandit log (alpha = 0.95)     5000
# 0   Dual Bandit log (alpha = 0.975)     5000
# 0    Dual Bandit log (alpha = 0.99)     5000
# 0   Dual Bandit log (alpha = 0.999)     5000
# 0  Dual Bandit log (alpha = 0.9999)     5000
# 0     Dual Bandit log (alpha = 1.0)     5000
# 	... optimal alpha = 1.0!

# %%
optimal_ll_strength_withlog
# Out:
# 1.0

# %%
optimal_svp_strength_nolog=0.1
optimal_svp_strength_withlog=2
optimal_ll_strength_nolog=0.0
optimal_ll_strength_withlog=1.0

# %%
for num_products in [10]:

    # Initialisation of different agents
    logging_agent = build_agent_init(
        'Logging',
        OrganicUserEventCounterAgent,
        {
            **organic_user_count_args,
            **std_env_args,
            'select_randomly': True,
            'reverse_pop': False,
            'epsilon': logging_epsilon
        }
    )

    skyline_agent = build_agent_init(
        'Skyline',
        SkylineAgent,
        {
            **skyline_args,
        }
    )

    likelihood_agent = build_agent_init(
        'Likelihood',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'll_IPS': False,
            'alpha': 1.0
        }
    )

    ips_likelihood_agent = build_agent_init(
        'IPS Likelihood',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'll_IPS': True,
            'alpha': 1.0
        }
    )

    cb_no_log_agent = build_agent_init(
        'Contextual Bandit - no log',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': False
        }
    )

    cb_log_agent = build_agent_init(
        'Contextual Bandit - with log',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': True
        }
    )

    poem_no_log_agent = build_agent_init(
        'POEM (lambda = {0} - no log)'.format(optimal_svp_strength_nolog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': False,
            'variance_penalisation_strength': optimal_svp_strength_nolog
        }
    )

    poem_log_agent = build_agent_init(
        'POEM (lambda = {0} - with log)'.format(optimal_svp_strength_withlog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': True,
            'variance_penalisation_strength': optimal_svp_strength_withlog
        }
    )

    dual_bandit_no_log_agent = build_agent_init(
        'Dual Bandit (alpha = {0} - no log)'.format(optimal_ll_strength_nolog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': False,
            'll_IPS': False,
            'alpha': optimal_ll_strength_nolog
        }
    )

    dual_bandit_log_agent = build_agent_init(
        'Dual Bandit (alpha = {0} - with log)'.format(optimal_ll_strength_withlog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': True,
            'll_IPS': False,
            'alpha': optimal_ll_strength_withlog
        }
    )

    agent_inits = {
        **logging_agent,
        **skyline_agent,
        **likelihood_agent,
        **ips_likelihood_agent,
        **cb_no_log_agent,
        **cb_log_agent
    }

    if optimal_svp_strength_nolog != 0:
        agent_inits.update(poem_no_log_agent)

    if optimal_svp_strength_withlog != 0:
        agent_inits.update(poem_log_agent)

    if optimal_ll_strength_nolog != 0 and optimal_ll_strength_nolog != 1:
        agent_inits.update(dual_bandit_no_log_agent)

    if optimal_ll_strength_withlog != 0 and optimal_ll_strength_withlog != 1:
        agent_inits.update(dual_bandit_log_agent)

    # Gathering performance of agents for the logging policy: popularity based.
    agent_stats01 = gather_agent_stats(
        env,
        std_env_args,
        {
            'num_products': num_products,
            'number_of_flips': num_products // 2,
            'agent': logger
        },
        agent_inits,
        TrainingDataSamples,
        TestingDataSamples,
        StatEpochs,
        StatEpochsNewRandomSeed
    )

    plot_agent_stats(agent_stats01, figname='performance_comparison_{0}_products_popular_eps{1}.png'.format(num_products,logging_epsilon))

    def tocsv(stats, file_name):
        import pandas as pd
        gg = stats[list(stats.keys())[1]]

        l = []
        for k in list(gg.keys()):
            f = pd.DataFrame(gg[k])
            f['Alg'] = k.replace('aa', 'a').replace('bb', 'b')
            f['Samples'] = stats[list(stats.keys())[0]]
            l.append(f)
        pd.concat(l).to_csv(file_name)

    tocsv(agent_stats01, 'performance_comparison_{0}_products_popular_eps{1}.csv'.format(num_products,logging_epsilon))
# Out:
# Agent: Logging
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (42.26357674598694s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (51.52306866645813s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (56.523990869522095s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (64.77133321762085s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (72.94895386695862s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (80.44882082939148s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (92.92737436294556s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (95.7773904800415s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (104.0212230682373s)
# Agent: Skyline
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (25.546368837356567s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (29.269263744354248s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (37.2596070766449s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (45.174559593200684s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (53.15479040145874s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (60.89388465881348s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (69.17687559127808s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (77.17787742614746s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (85.39194083213806s)
# Agent: Likelihood
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (363.42484855651855s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (390.5590777397156s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (438.90632796287537s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (483.6258764266968s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (555.1888394355774s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (677.6173584461212s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (765.8644821643829s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (876.0850389003754s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (939.2234477996826s)
# Agent: IPS Likelihood
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (415.47313928604126s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (436.4090759754181s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (489.40736055374146s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (702.1963987350464s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (817.0855696201324s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (715.1295704841614s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (785.0756711959839s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (699.329423904419s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (854.6693563461304s)
# Agent: Contextual Bandit - no log
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (430.29842042922974s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (414.7241644859314s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (458.4486126899719s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (514.8768203258514s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (536.2697565555573s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (566.8760094642639s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (614.8419413566589s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (627.5539186000824s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (714.7547571659088s)
# Agent: Contextual Bandit - with log
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (400.39559745788574s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (414.4179072380066s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (466.2169189453125s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (509.0811629295349s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (496.94552302360535s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (586.4586491584778s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (605.9964072704315s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (654.5644328594208s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (698.6969032287598s)
# Agent: POEM (lambda = 0.1 - no log)
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (379.6622130870819s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (355.12011766433716s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (433.9415020942688s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (470.0624644756317s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (501.28048825263977s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (568.5245242118835s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (598.5799922943115s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (605.5483708381653s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (661.0862555503845s)
# Agent: POEM (lambda = 0.5 - with log)
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (366.2266912460327s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (386.29896664619446s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (400.8456289768219s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (442.32076692581177s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (505.8423614501953s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (534.2192299365997s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (562.0347962379456s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (636.987895488739s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (691.4132266044617s)
