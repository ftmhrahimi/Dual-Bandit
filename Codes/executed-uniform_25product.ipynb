# %%
import gym
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from agents import OrganicUserEventCounterAgent, organic_user_count_args
from agents import SkylineAgent, skyline_args
from agents import RandomAgent, random_args

from agents import PyTorchMLRAgent, pytorch_mlr_args
from datetime import datetime

# %%
import gym
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from agents import OrganicUserEventCounterAgent, organic_user_count_args
from agents import SkylineAgent, skyline_args
from agents import RandomAgent, random_args
from reco_gym import (
    Configuration,
    build_agent_init,
    env_1_args,
    gather_agent_stats,
    plot_agent_stats
)

from agents import PyTorchMLRAgent, pytorch_mlr_args
from datetime import datetime

# General parameters for experiments
RandomSeed = 42
TrainingDataSamples = [1000, 2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000]
TestingDataSamples = 10000
StatEpochs = 5
StatEpochsNewRandomSeed = True

def grid_search_parameter(
        parameter_name, parameter_values,
        agent_name, agent_pytorch_mlr_args,
        env_args, extra_env_args,
        train_samples=5000, valid_samples=10000, valid_runs=5,
):
    ''' Perform a grid search by doing an A/B test with model variants that use different parameter values, log the rsult and return the optimal parameter value '''
    print(f'\tGrid search for {agent_name}')
    grid_search_agent_inits = dict()
    for parameter_value in parameter_values:
        agent_name_with_specified_parameter = f'{agent_name} ({parameter_name} = {parameter_value})'
        grid_search_agent_inits.update(
            build_agent_init(
                agent_name_with_specified_parameter,
                PyTorchMLRAgent,
                {
                    **agent_pytorch_mlr_args,
                    parameter_name: parameter_value
                }
            )
        )

    ### Run A/B test with model variants
    agent_stats = gather_agent_stats(
        env,
        env_args,
        {
            **extra_env_args
        },
        grid_search_agent_inits,
        [train_samples],
        valid_samples,
        valid_runs,
        StatEpochsNewRandomSeed
    )

    # Messy way to get everything into pandas, but it works 
    gg = agent_stats[list(agent_stats.keys())[1]]
    l = []
    for k in list(gg.keys()):
        f = pd.DataFrame(gg[k])
        f['Alg'] = k
        f['Samples'] = agent_stats[list(agent_stats.keys())[0]]
        l.append(f)
    agent_stats_df = pd.concat(l)
    agent_stats_df.columns = [str(c) for c in agent_stats_df.columns]
    values = agent_stats_df['AgentStats.Q0_500'].values
    optimal_parameter_value = parameter_values[np.argmax(values)]
    print(agent_stats_df)
    agent_stats_df.to_csv(f'GS_{agent_name.replace(" ", "_")}_pop.csv', index=False)
    print(f'\t... optimal {parameter_name} = {optimal_parameter_value}!')
    return optimal_parameter_value

num_products=25
print('#' * 48)
print(f'{datetime.now()}\tLogging Popularity with {num_products} products...')
print('#' * 48)

    # Environment parameters
std_env_args = {
    **env_1_args,
    'random_seed': RandomSeed,
    'num_products': num_products,
}
env = gym.make('reco-gym-v1')

# Logging policy
logger = RandomAgent(Configuration({**random_args,**std_env_args}))

std_extra_env_args = {
    'num_products': num_products,
    'number_of_flips': num_products // 2,
    'agent': logger,
}

    ###################################################
    # Grid searches for POEM and Dual Bandit variants #
    ###################################################
# Out:
# ################################################
# 2022-02-22 23:02:31.979945	Logging Popularity with 25 products...
# ################################################

# %%
 # Original POEM
lambdas_poem_no_log = [.0, .05, .1, .25, .5, 1.0, 2.0]
poem_no_log_mlr_args = {
    **pytorch_mlr_args,
    'logIPS': False,    }
optimal_svp_strength_nolog = grid_search_parameter(
    'variance_penalisation_strength', lambdas_poem_no_log,
    'POEM no log', poem_no_log_mlr_args,
    std_env_args, std_extra_env_args,
)
# Out:
# 	Grid search for POEM no log
# Agent: POEM no log (variance_penalisation_strength = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (476.54428219795227s)
# Agent: POEM no log (variance_penalisation_strength = 0.05)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (511.77891397476196s)
# Agent: POEM no log (variance_penalisation_strength = 0.1)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (548.8641905784607s)
# Agent: POEM no log (variance_penalisation_strength = 0.25)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (523.3113524913788s)
# Agent: POEM no log (variance_penalisation_strength = 0.5)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (512.6694707870483s)
# Agent: POEM no log (variance_penalisation_strength = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (517.8485088348389s)
# Agent: POEM no log (variance_penalisation_strength = 2.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (566.615469455719s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.021081           0.021224           0.021369
# 0           0.019816           0.019955           0.020095
# 0           0.019815           0.019954           0.020094
# 0           0.020388           0.020529           0.020671
# 0           0.019571           0.019710           0.019848
# 0           0.021089           0.021233           0.021377
# 0           0.019913           0.020052           0.020192
#
#                                                  Alg  Samples
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 	... optimal variance_penalisation_strength = 1.0!

# %%
optimal_svp_strength_nolog
# Out:
# 1.0

# %%
# Logarithmic POEM
lambdas_poem_log = [0.0, .05, .1, .25, .5, 1.0, 2.0]
poem_log_mlr_args = {
    **pytorch_mlr_args,
    'logIPS': True,
}
optimal_svp_strength_withlog = grid_search_parameter(
    'variance_penalisation_strength', lambdas_poem_log,
    'POEM log', poem_log_mlr_args,
    std_env_args, std_extra_env_args,
)
# Out:
# 	Grid search for POEM log
# Agent: POEM log (variance_penalisation_strength = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (518.4925441741943s)
# Agent: POEM log (variance_penalisation_strength = 0.05)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (482.3319470882416s)
# Agent: POEM log (variance_penalisation_strength = 0.1)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (477.70350313186646s)
# Agent: POEM log (variance_penalisation_strength = 0.25)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (489.368763923645s)
# Agent: POEM log (variance_penalisation_strength = 0.5)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (482.78381967544556s)
# Agent: POEM log (variance_penalisation_strength = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (453.2835235595703s)
# Agent: POEM log (variance_penalisation_strength = 2.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (454.93849873542786s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.018225           0.018359           0.018493
# 0           0.017963           0.018095           0.018228
# 0           0.018048           0.018181           0.018314
# 0           0.017966           0.018098           0.018231
# 0           0.018004           0.018137           0.018270
# 0           0.018053           0.018186           0.018319
# 0           0.018011           0.018143           0.018276
#
#                                                 Alg  Samples
# 0   POEM log (variance_penalisation_strength = 0.0)     5000
# 0  POEM log (variance_penalisation_strength = 0.05)     5000
# 0   POEM log (variance_penalisation_strength = 0.1)     5000
# 0  POEM log (variance_penalisation_strength = 0.25)     5000
# 0   POEM log (variance_penalisation_strength = 0.5)     5000
# 0   POEM log (variance_penalisation_strength = 1.0)     5000
# 0   POEM log (variance_penalisation_strength = 2.0)     5000
# 	... optimal variance_penalisation_strength = 0.0!

# %%
optimal_svp_strength_withlog
# Out:
# 0.0

# %%
# Dual Bandit
alphas_dual_bandit_no_log = [.0, .80, .85, .90, .925, .95, .975, .99, .999, .9999, 1.0]
dual_bandit_no_log_mlr_args = {
    **pytorch_mlr_args,
    'logIPS': False,
    'll_IPS': False,
}
optimal_ll_strength_nolog = grid_search_parameter(
    'alpha', alphas_dual_bandit_no_log,
    'Dual Bandit no log', dual_bandit_no_log_mlr_args,
    std_env_args, std_extra_env_args,
)
# Out:
# 	Grid search for Dual Bandit no log
# Agent: Dual Bandit no log (alpha = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (452.7324011325836s)
# Agent: Dual Bandit no log (alpha = 0.8)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (812.2879424095154s)
# Agent: Dual Bandit no log (alpha = 0.85)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (755.975997209549s)
# Agent: Dual Bandit no log (alpha = 0.9)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (712.2758073806763s)
# Agent: Dual Bandit no log (alpha = 0.925)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (729.351945400238s)
# Agent: Dual Bandit no log (alpha = 0.95)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (577.0510857105255s)
# Agent: Dual Bandit no log (alpha = 0.975)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (493.17095017433167s)
# Agent: Dual Bandit no log (alpha = 0.99)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (503.94745206832886s)
# Agent: Dual Bandit no log (alpha = 0.999)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (499.92115688323975s)
# Agent: Dual Bandit no log (alpha = 0.9999)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (453.4241783618927s)
# Agent: Dual Bandit no log (alpha = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (476.01617908477783s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.018935           0.019071           0.019208
# 0           0.020305           0.020446           0.020587
# 0           0.019717           0.019856           0.019995
# 0           0.019739           0.019878           0.020017
# 0           0.019565           0.019703           0.019842
# 0           0.019213           0.019350           0.019487
# 0           0.018515           0.018649           0.018784
# 0           0.018255           0.018388           0.018522
# 0           0.018327           0.018460           0.018595
# 0           0.018146           0.018279           0.018413
# 0           0.018224           0.018357           0.018491
#
#                                    Alg  Samples
# 0     Dual Bandit no log (alpha = 0.0)     5000
# 0     Dual Bandit no log (alpha = 0.8)     5000
# 0    Dual Bandit no log (alpha = 0.85)     5000
# 0     Dual Bandit no log (alpha = 0.9)     5000
# 0   Dual Bandit no log (alpha = 0.925)     5000
# 0    Dual Bandit no log (alpha = 0.95)     5000
# 0   Dual Bandit no log (alpha = 0.975)     5000
# 0    Dual Bandit no log (alpha = 0.99)     5000
# 0   Dual Bandit no log (alpha = 0.999)     5000
# 0  Dual Bandit no log (alpha = 0.9999)     5000
# 0     Dual Bandit no log (alpha = 1.0)     5000
# 	... optimal alpha = 0.8!

# %%
optimal_ll_strength_nolog
# Out:
# 0.8

# %%
# Logarithmic Dual Bandit
alphas_dual_bandit_log = [.0, .80, .85, .90, .925, .95, .975, .99, .999, .9999, 1.0]
dual_bandit_log_mlr_args = {
    **pytorch_mlr_args,
    'logIPS': True,
    'll_IPS': False,
}
optimal_ll_strength_withlog = grid_search_parameter(
    'alpha', alphas_dual_bandit_log,
    'Dual Bandit log', dual_bandit_log_mlr_args,
    std_env_args, std_extra_env_args,
)
# Out:
# 	Grid search for Dual Bandit log
# Agent: Dual Bandit log (alpha = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (434.16187810897827s)
# Agent: Dual Bandit log (alpha = 0.8)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (463.26503443717957s)
# Agent: Dual Bandit log (alpha = 0.85)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (474.8029725551605s)
# Agent: Dual Bandit log (alpha = 0.9)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (484.92272210121155s)
# Agent: Dual Bandit log (alpha = 0.925)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (474.8036239147186s)
# Agent: Dual Bandit log (alpha = 0.95)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (454.1648578643799s)
# Agent: Dual Bandit log (alpha = 0.975)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (489.32450795173645s)
# Agent: Dual Bandit log (alpha = 0.99)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (506.78130650520325s)
# Agent: Dual Bandit log (alpha = 0.999)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (479.68666553497314s)
# Agent: Dual Bandit log (alpha = 0.9999)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (504.6057958602905s)
# Agent: Dual Bandit log (alpha = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (460.629408121109s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.018104           0.018237           0.018370
# 0           0.017984           0.018116           0.018249
# 0           0.017754           0.017885           0.018017
# 0           0.018176           0.018309           0.018442
# 0           0.018226           0.018359           0.018493
# 0           0.018176           0.018309           0.018443
# 0           0.018140           0.018273           0.018407
# 0           0.017978           0.018110           0.018243
# 0           0.018087           0.018220           0.018353
# 0           0.018154           0.018287           0.018420
# 0           0.018210           0.018343           0.018477
#
#                                 Alg  Samples
# 0     Dual Bandit log (alpha = 0.0)     5000
# 0     Dual Bandit log (alpha = 0.8)     5000
# 0    Dual Bandit log (alpha = 0.85)     5000
# 0     Dual Bandit log (alpha = 0.9)     5000
# 0   Dual Bandit log (alpha = 0.925)     5000
# 0    Dual Bandit log (alpha = 0.95)     5000
# 0   Dual Bandit log (alpha = 0.975)     5000
# 0    Dual Bandit log (alpha = 0.99)     5000
# 0   Dual Bandit log (alpha = 0.999)     5000
# 0  Dual Bandit log (alpha = 0.9999)     5000
# 0     Dual Bandit log (alpha = 1.0)     5000
# 	... optimal alpha = 0.925!

# %%
optimal_ll_strength_withlog
# Out:
# 0.925

# %%
optimal_svp_strength_nolog=1.0
optimal_svp_strength_withlog=0.0
optimal_ll_strength_nolog=0.8
optimal_ll_strength_withlog=0.925

# %%
for num_products in [25]:
# Initialisation of different agents
    logging_agent = build_agent_init(
        'Logging',
        RandomAgent,
        {
            **random_args,
            **std_env_args,
        }
    )

    skyline_agent = build_agent_init(
        'Skyline',
        SkylineAgent,
        {
            **skyline_args,
        }
    )

    likelihood_agent = build_agent_init(
        'Likelihood',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'll_IPS': False,
            'alpha': 1.0
        }
    )

    ips_likelihood_agent = build_agent_init(
        'IPS Likelihood',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'll_IPS': True,
            'alpha': 1.0
        }
    )

    cb_no_log_agent = build_agent_init(
        'Contextual Bandit - no log',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': False
        }
    )

    cb_log_agent = build_agent_init(
        'Contextual Bandit - with log',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': True
        }
    )

    poem_no_log_agent = build_agent_init(
        'POEM (lambda = {0} - no log)'.format(optimal_svp_strength_nolog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': False,
            'variance_penalisation_strength': optimal_svp_strength_nolog
        }
    )

    poem_log_agent = build_agent_init(
        'POEM (lambda = {0} - with log)'.format(optimal_svp_strength_withlog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': True,
            'variance_penalisation_strength': optimal_svp_strength_withlog
        }
    )

    dual_bandit_no_log_agent = build_agent_init(
        'Dual Bandit (alpha = {0} - no log)'.format(optimal_ll_strength_nolog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': False,
            'll_IPS': False,
            'alpha': optimal_ll_strength_nolog
        }
    )

    dual_bandit_log_agent = build_agent_init(
        'Dual Bandit (alpha = {0} - with log)'.format(optimal_ll_strength_withlog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': True,
            'll_IPS': False,
            'alpha': optimal_ll_strength_withlog
        }
    )

    agent_inits = {
        **logging_agent,
        **skyline_agent,
        **likelihood_agent,
        **ips_likelihood_agent,
        **cb_no_log_agent,
        **cb_log_agent
    }

    if optimal_svp_strength_nolog != 0:
        agent_inits.update(poem_no_log_agent)

    if optimal_svp_strength_withlog != 0:
        agent_inits.update(poem_log_agent)

    if optimal_ll_strength_nolog != 0 and optimal_ll_strength_nolog != 1:
        agent_inits.update(dual_bandit_no_log_agent)

    if optimal_ll_strength_withlog != 0 and optimal_ll_strength_withlog != 1:
        agent_inits.update(dual_bandit_log_agent)

    # Gathering performance of agents for the logging policy: uniform.
    agent_stats01 = gather_agent_stats(
        env,
        std_env_args,
        {
            'num_products': num_products,
            'number_of_flips': num_products // 2,
            'agent': logger
        },
        agent_inits,
        TrainingDataSamples,
        TestingDataSamples,
        StatEpochs,
        StatEpochsNewRandomSeed
    )

    plot_agent_stats(agent_stats01, figname='performance_comparison_{0}_products_uniform.png'.format(num_products))

    def tocsv(stats, file_name):
        import pandas as pd
        gg = stats[list(stats.keys())[1]]

        l = []
        for k in list(gg.keys()):
            f = pd.DataFrame(gg[k])
            f['Alg'] = k.replace('aa', 'a').replace('bb', 'b')
            f['Samples'] = stats[list(stats.keys())[0]]
            l.append(f)
        pd.concat(l).to_csv(file_name)

    tocsv(agent_stats01, 'performance_comparison_{0}_products_uniform.csv'.format(num_products))
# Out:
# Agent: Logging
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (27.172407150268555s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (30.472541093826294s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (35.9142050743103s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (40.4946494102478s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (45.451738595962524s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (50.108731508255005s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (55.082677602767944s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (60.32580256462097s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (64.54973721504211s)
# Agent: Skyline
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (25.890389680862427s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (28.37426781654358s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (33.620911836624146s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (38.88492465019226s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (44.16204023361206s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (49.16261601448059s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (54.53991413116455s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (60.0225567817688s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (64.95672512054443s)
# Agent: Likelihood
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (406.70170736312866s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (436.2424147129059s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (447.82314920425415s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (486.1036002635956s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (596.8653390407562s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (546.7214090824127s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (625.3035750389099s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (676.6455128192902s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (742.2041006088257s)
# Agent: IPS Likelihood
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (398.9918863773346s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (461.52690625190735s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (527.4969029426575s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (726.7653996944427s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (1003.1835246086121s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (1063.7822906970978s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (1303.0507278442383s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (1423.5304560661316s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (1678.3945138454437s)
# Agent: Contextual Bandit - no log
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (376.7097737789154s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (414.21607661247253s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (459.47562646865845s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (478.59286999702454s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (506.44619369506836s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (541.1636815071106s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (572.1514325141907s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (628.9805219173431s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (683.9564967155457s)
# Agent: Contextual Bandit - with log
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (368.972496509552s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (392.2838513851166s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (417.78211426734924s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (483.332466840744s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (473.23777532577515s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (515.3694026470184s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (594.4105176925659s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (604.0529568195343s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (651.1033442020416s)
# Agent: POEM (lambda = 1.0 - no log)
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (389.4926326274872s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (381.2675156593323s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (405.76475524902344s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (504.45845127105713s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (539.7507894039154s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (575.7394530773163s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (613.4323360919952s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (596.2323973178864s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (675.4380910396576s)
# Agent: Dual Bandit (alpha = 0.8 - no log)
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (425.7706801891327s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (546.5761575698853s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (768.7515394687653s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (901.6481935977936s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (1193.1324479579926s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (1428.6707689762115s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (1564.6571357250214s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (1709.8399560451508s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (1868.5191385746002s)
# Agent: Dual Bandit (alpha = 0.925 - with log)
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (376.89027309417725s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (397.45932388305664s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (465.667937040329s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (496.567843914032s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (534.7632751464844s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (560.4703698158264s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (628.2579956054688s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (668.0582962036133s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (727.3388366699219s)
