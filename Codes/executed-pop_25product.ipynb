# %%
import gym
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from agents import OrganicUserEventCounterAgent, organic_user_count_args
from agents import SkylineAgent, skyline_args
from agents import RandomAgent, random_args

from agents import PyTorchMLRAgent, pytorch_mlr_args
from datetime import datetime

# %%
import gym
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from agents import OrganicUserEventCounterAgent, organic_user_count_args
from agents import SkylineAgent, skyline_args
from agents import RandomAgent, random_args
from reco_gym import (
    Configuration,
    build_agent_init,
    env_1_args,
    gather_agent_stats,
    plot_agent_stats
)

from agents import PyTorchMLRAgent, pytorch_mlr_args
from datetime import datetime

# General parameters for experiments
RandomSeed = 42
TrainingDataSamples = [1000, 2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000]
TestingDataSamples = 10000
StatEpochs = 5
StatEpochsNewRandomSeed = True

def grid_search_parameter(
        parameter_name, parameter_values,
        agent_name, agent_pytorch_mlr_args,
        env_args, extra_env_args,
        train_samples=5000, valid_samples=10000, valid_runs=5,
):
    ''' Perform a grid search by doing an A/B test with model variants that use different parameter values, log the rsult and return the optimal parameter value '''
    print(f'\tGrid search for {agent_name}')
    grid_search_agent_inits = dict()
    for parameter_value in parameter_values:
        agent_name_with_specified_parameter = f'{agent_name} ({parameter_name} = {parameter_value})'
        grid_search_agent_inits.update(
            build_agent_init(
                agent_name_with_specified_parameter,
                PyTorchMLRAgent,
                {
                    **agent_pytorch_mlr_args,
                    parameter_name: parameter_value
                }
            )
        )

    ### Run A/B test with model variants
    agent_stats = gather_agent_stats(
        env,
        env_args,
        {
            **extra_env_args
        },
        grid_search_agent_inits,
        [train_samples],
        valid_samples,
        valid_runs,
        StatEpochsNewRandomSeed
    )

    # Messy way to get everything into pandas, but it works 
    gg = agent_stats[list(agent_stats.keys())[1]]
    l = []
    for k in list(gg.keys()):
        f = pd.DataFrame(gg[k])
        f['Alg'] = k
        f['Samples'] = agent_stats[list(agent_stats.keys())[0]]
        l.append(f)
    agent_stats_df = pd.concat(l)
    agent_stats_df.columns = [str(c) for c in agent_stats_df.columns]
    values = agent_stats_df['AgentStats.Q0_500'].values
    optimal_parameter_value = parameter_values[np.argmax(values)]
    print(agent_stats_df)
    agent_stats_df.to_csv(f'GS_{agent_name.replace(" ", "_")}_pop.csv', index=False)
    print(f'\t... optimal {parameter_name} = {optimal_parameter_value}!')
    return optimal_parameter_value

for num_products in [25]:
    print('#' * 48)
    print(f'{datetime.now()}\tLogging Popularity with {num_products} products...')
    print('#' * 48)

    # Environment parameters
    std_env_args = {
        **env_1_args,
        'random_seed': RandomSeed,
        'num_products': num_products,
    }
    env = gym.make('reco-gym-v1')

    # Logging policy
    logger = OrganicUserEventCounterAgent(Configuration({
        **organic_user_count_args,
        **std_env_args,
        'select_randomly': True,
        'epsilon': 0
    }))

    std_extra_env_args = {
        'num_products': num_products,
        'number_of_flips': num_products // 2,
        'agent': logger,
    }
# Out:
# ################################################
# 2022-02-24 20:58:38.459091	Logging Popularity with 25 products...
# ################################################

# %%
    ###################################################
    # Grid searches for POEM and Dual Bandit variants #
    ###################################################

    # Original POEM
    lambdas_poem_no_log = [.0, .05, .1, .25, .5, 1.0, 2.0]
    poem_no_log_mlr_args = {
        **pytorch_mlr_args,
        'logIPS': False,
    }
    optimal_svp_strength_nolog = grid_search_parameter(
        'variance_penalisation_strength', lambdas_poem_no_log,
        'POEM no log', poem_no_log_mlr_args,
        std_env_args, std_extra_env_args,
    )

    # Logarithmic POEM
    lambdas_poem_log = [.0, .05, .1, .25, .5, 1.0, 2.0]
    poem_log_mlr_args = {
        **pytorch_mlr_args,
        'logIPS': True,
    }
    optimal_svp_strength_withlog = grid_search_parameter(
        'variance_penalisation_strength', lambdas_poem_log,
        'POEM log', poem_log_mlr_args,
        std_env_args, std_extra_env_args,
    )

    # Dual Bandit
    alphas_dual_bandit_no_log = [.0, .80, .85, .90, .925, .95, .975, .99, .999, .9999, 1.0]
    dual_bandit_no_log_mlr_args = {
        **pytorch_mlr_args,
        'logIPS': False,
        'll_IPS': False,
    }
    optimal_ll_strength_nolog = grid_search_parameter(
        'alpha', alphas_dual_bandit_no_log,
        'Dual Bandit no log', dual_bandit_no_log_mlr_args,
        std_env_args, std_extra_env_args,
    )

    # Logarithmic Dual Bandit
    alphas_dual_bandit_log = [.0, .80, .85, .90, .925, .95, .975, .99, .999, .9999, 1.0]
    dual_bandit_log_mlr_args = {
        **pytorch_mlr_args,
        'logIPS': True,
        'll_IPS': False,
    }
    optimal_ll_strength_withlog = grid_search_parameter(
        'alpha', alphas_dual_bandit_log,
        'Dual Bandit log', dual_bandit_log_mlr_args,
        std_env_args, std_extra_env_args,
    )
# Out:
# ################################################
# 2022-02-21 22:49:45.808291	Logging Popularity with 25 products...
# ################################################
# 	Grid search for POEM no log
# Agent: POEM no log (variance_penalisation_strength = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (489.5427415370941s)
# Agent: POEM no log (variance_penalisation_strength = 0.05)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (492.6231608390808s)
# Agent: POEM no log (variance_penalisation_strength = 0.1)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (467.5975284576416s)
# Agent: POEM no log (variance_penalisation_strength = 0.25)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (469.44070267677307s)
# Agent: POEM no log (variance_penalisation_strength = 0.5)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (482.1538259983063s)
# Agent: POEM no log (variance_penalisation_strength = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (501.1817591190338s)
# Agent: POEM no log (variance_penalisation_strength = 2.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (475.2582368850708s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.010204           0.010303           0.010403
# 0           0.010243           0.010342           0.010442
# 0           0.011073           0.011177           0.011281
# 0           0.010451           0.010552           0.010653
# 0           0.009677           0.009774           0.009871
# 0           0.011265           0.011369           0.011474
# 0           0.010021           0.010120           0.010219
#
#                                                  Alg  Samples
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 0  POEM no log (variance_penalisation_strength = ...     5000
# 	... optimal variance_penalisation_strength = 1.0!
# 	Grid search for POEM log
# Agent: POEM log (variance_penalisation_strength = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (462.4300308227539s)
# Agent: POEM log (variance_penalisation_strength = 0.05)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (478.7713305950165s)
# Agent: POEM log (variance_penalisation_strength = 0.1)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (484.27486634254456s)
# Agent: POEM log (variance_penalisation_strength = 0.25)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (449.7734696865082s)
# Agent: POEM log (variance_penalisation_strength = 0.5)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (465.4394211769104s)
# Agent: POEM log (variance_penalisation_strength = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (466.2202157974243s)
# Agent: POEM log (variance_penalisation_strength = 2.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (459.60738134384155s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.012470           0.012580           0.012691
# 0           0.012075           0.012183           0.012292
# 0           0.012066           0.012174           0.012283
# 0           0.012485           0.012594           0.012705
# 0           0.012430           0.012539           0.012650
# 0           0.012491           0.012601           0.012711
# 0           0.012386           0.012496           0.012606
#
#                                                 Alg  Samples
# 0   POEM log (variance_penalisation_strength = 0.0)     5000
# 0  POEM log (variance_penalisation_strength = 0.05)     5000
# 0   POEM log (variance_penalisation_strength = 0.1)     5000
# 0  POEM log (variance_penalisation_strength = 0.25)     5000
# 0   POEM log (variance_penalisation_strength = 0.5)     5000
# 0   POEM log (variance_penalisation_strength = 1.0)     5000
# 0   POEM log (variance_penalisation_strength = 2.0)     5000
# 	... optimal variance_penalisation_strength = 1.0!
# 	Grid search for Dual Bandit no log
# Agent: Dual Bandit no log (alpha = 0.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (492.61714363098145s)
# Agent: Dual Bandit no log (alpha = 0.8)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (735.9885973930359s)
# Agent: Dual Bandit no log (alpha = 0.85)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (654.7044129371643s)
# Agent: Dual Bandit no log (alpha = 0.9)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (660.7327611446381s)
# Agent: Dual Bandit no log (alpha = 0.925)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (728.6058814525604s)
# Agent: Dual Bandit no log (alpha = 0.95)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (667.6942503452301s)
# Agent: Dual Bandit no log (alpha = 0.975)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (596.2469825744629s)
# Agent: Dual Bandit no log (alpha = 0.99)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (715.6478922367096s)
# Agent: Dual Bandit no log (alpha = 0.999)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (682.6629526615143s)
# Agent: Dual Bandit no log (alpha = 0.9999)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (624.0220921039581s)
# Agent: Dual Bandit no log (alpha = 1.0)
# Start: Num of Offline Users: 5000
# End: Num of Offline Users: 5000 (616.3667862415314s)
#    AgentStats.Q0_025  AgentStats.Q0_500  AgentStats.Q0_975  \
# 0           0.010886           0.010989           0.011092
# 0           0.011726           0.011832           0.011940
# 0           0.011987           0.012095           0.012203
# 0           0.012148           0.012256           0.012366
# 0           0.012466           0.012576           0.012687
# 0           0.012387           0.012496           0.012606
# 0           0.013541           0.013656           0.013771
# 0           0.013439           0.013553           0.013668
# 0           0.012418           0.012527           0.012638
# 0           0.012397           0.012506           0.012616
# 0           0.008833           0.008925           0.009018
#
#                                    Alg  Samples
# 0     Dual Bandit no log (alpha = 0.0)     5000
# 0     Dual Bandit no log (alpha = 0.8)     5000
# 0    Dual Bandit no log (alpha = 0.85)     5000
# 0     Dual Bandit no log (alpha = 0.9)     5000
# 0   Dual Bandit no log (alpha = 0.925)     5000
# 0    Dual Bandit no log (alpha = 0.95)     5000
# 0   Dual Bandit no log (alpha = 0.975)     5000
# 0    Dual Bandit no log (alpha = 0.99)     5000
# 0   Dual Bandit no log (alpha = 0.999)     5000
# 0  Dual Bandit no log (alpha = 0.9999)     5000
# 0     Dual Bandit no log (alpha = 1.0)     5000
# 	... optimal alpha = 0.975!
# 	Grid search for Dual Bandit log
# Agent: Dual Bandit log (alpha = 0.0)
# Start: Num of Offline Users: 5000

# %%
optimal_svp_strength_nolog=1.0
optimal_svp_strength_withlog=1.0
optimal_ll_strength_nolog=0.975
optimal_ll_strength_withlog=0.999

# %%
for num_products in [25]:
# Initialisation of different agents
    logging_agent = build_agent_init(
        'Logging',
        OrganicUserEventCounterAgent,
        {
            **organic_user_count_args,
            **std_env_args,
            'select_randomly': True,
            'reverse_pop': False,
            'epsilon': 0
        }
    )

    skyline_agent = build_agent_init(
        'Skyline',
        SkylineAgent,
        {
            **skyline_args,
        }
    )

    likelihood_agent = build_agent_init(
        'Likelihood',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'll_IPS': False,
            'alpha': 1.0
        }
    )

    ips_likelihood_agent = build_agent_init(
        'IPS Likelihood',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'll_IPS': True,
            'alpha': 1.0
        }
    )

    cb_no_log_agent = build_agent_init(
        'Contextual Bandit - no log',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': False
        }
    )

    cb_log_agent = build_agent_init(
        'Contextual Bandit - with log',
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': True
        }
    )

    poem_no_log_agent = build_agent_init(
        'POEM (lambda = {0} - no log)'.format(optimal_svp_strength_nolog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': False,
            'variance_penalisation_strength': optimal_svp_strength_nolog
        }
    )

    poem_log_agent = build_agent_init(
        'POEM (lambda = {0} - with log)'.format(optimal_svp_strength_withlog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': True,
            'variance_penalisation_strength': optimal_svp_strength_withlog
        }
    )

    dual_bandit_no_log_agent = build_agent_init(
        'Dual Bandit (alpha = {0} - no log)'.format(optimal_ll_strength_nolog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': False,
            'll_IPS': False,
            'alpha': optimal_ll_strength_nolog
        }
    )

    dual_bandit_log_agent = build_agent_init(
        'Dual Bandit (alpha = {0} - with log)'.format(optimal_ll_strength_withlog),
        PyTorchMLRAgent,
        {
            **pytorch_mlr_args,
            'logIPS': True,
            'll_IPS': False,
            'alpha': optimal_ll_strength_withlog
        }
    )

    agent_inits = {
        **logging_agent,
        **skyline_agent,
        **likelihood_agent,
        **ips_likelihood_agent,
        **cb_no_log_agent,
        **cb_log_agent
    }

    if optimal_svp_strength_nolog != 0:
        agent_inits.update(poem_no_log_agent)

    if optimal_svp_strength_withlog != 0:
        agent_inits.update(poem_log_agent)

    if optimal_ll_strength_nolog != 0 and optimal_ll_strength_nolog != 1:
        agent_inits.update(dual_bandit_no_log_agent)

    if optimal_ll_strength_withlog != 0 and optimal_ll_strength_withlog != 1:
        agent_inits.update(dual_bandit_log_agent)

    # Gathering performance of agents for the logging policy: popularity based.
    agent_stats01 = gather_agent_stats(
        env,
        std_env_args,
        {
            'num_products': num_products,
            'number_of_flips': num_products // 2,
            'agent': logger
        },
        agent_inits,
        TrainingDataSamples,
        TestingDataSamples,
        StatEpochs,
        StatEpochsNewRandomSeed
    )

    plot_agent_stats(agent_stats01, figname='performance_comparison_{0}_products_popular.png'.format(num_products))

    def tocsv(stats, file_name):
        import pandas as pd
        gg = stats[list(stats.keys())[1]]

        l = []
        for k in list(gg.keys()):
            f = pd.DataFrame(gg[k])
            f['Alg'] = k.replace('aa', 'a').replace('bb', 'b')
            f['Samples'] = stats[list(stats.keys())[0]]
            l.append(f)
        pd.concat(l).to_csv(file_name)

    tocsv(agent_stats01, 'performance_comparison_{0}_products_popular.csv'.format(num_products))
# Out:
# Agent: Logging
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (35.54556965827942s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (40.22225832939148s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (47.18147301673889s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (53.741917848587036s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (60.36565160751343s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (67.62875533103943s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (73.55231046676636s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (80.18322086334229s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (86.81870913505554s)
# Agent: Skyline
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (26.781132698059082s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (29.627424001693726s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (36.33050465583801s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (42.74844574928284s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (49.62120962142944s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (56.2158477306366s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (62.68642282485962s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (69.33591175079346s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (75.89979219436646s)
# Agent: Likelihood
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (402.0785593986511s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (442.8360323905945s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (510.9226133823395s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (595.6814796924591s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (895.2569653987885s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (587.574310541153s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (1038.0644528865814s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (1176.6520895957947s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (1374.3058822154999s)
# Agent: IPS Likelihood
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (433.9046080112457s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (425.12887620925903s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (547.6753323078156s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (778.6407098770142s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (690.4590740203857s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (917.2585504055023s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (1356.9276094436646s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (1435.5586280822754s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (1580.3774282932281s)
# Agent: Contextual Bandit - no log
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (358.96551275253296s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (396.41598534584045s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (428.81781673431396s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (432.8347895145416s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (500.5026113986969s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (532.6786170005798s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (583.8077991008759s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (641.7453427314758s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (671.9463276863098s)
# Agent: Contextual Bandit - with log
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (352.36150217056274s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (394.288569688797s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (432.5462393760681s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (453.0301208496094s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (480.4826092720032s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (558.5313436985016s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (555.1683969497681s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (627.9371626377106s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (647.8741610050201s)
# Agent: POEM (lambda = 1.0 - no log)
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (365.147429227829s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (395.0715265274048s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (382.87305068969727s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (465.3121888637543s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (512.9789273738861s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (532.7689559459686s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (574.9516994953156s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (627.73361992836s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (653.7613427639008s)
# Agent: POEM (lambda = 1.0 - with log)
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (411.5638310909271s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (394.21005940437317s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (423.8549699783325s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (458.4754595756531s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (476.8341543674469s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (522.3707342147827s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (544.7890472412109s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (624.4606311321259s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (656.4843215942383s)
# Agent: Dual Bandit (alpha = 0.975 - no log)
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (406.8533446788788s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (403.92993783950806s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (526.5200316905975s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (590.4333808422089s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (784.3729791641235s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (732.6129887104034s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (824.3497865200043s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (673.6021251678467s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (1369.5233733654022s)
# Agent: Dual Bandit (alpha = 0.999 - with log)
# Start: Num of Offline Users: 1000
# End: Num of Offline Users: 1000 (377.2926781177521s)
# Start: Num of Offline Users: 2000
# End: Num of Offline Users: 2000 (432.303866147995s)
# Start: Num of Offline Users: 4000
# End: Num of Offline Users: 4000 (435.8126528263092s)
# Start: Num of Offline Users: 6000
# End: Num of Offline Users: 6000 (633.1679191589355s)
# Start: Num of Offline Users: 8000
# End: Num of Offline Users: 8000 (659.7479343414307s)
# Start: Num of Offline Users: 10000
# End: Num of Offline Users: 10000 (727.5363352298737s)
# Start: Num of Offline Users: 12000
# End: Num of Offline Users: 12000 (1030.9897894859314s)
# Start: Num of Offline Users: 14000
# End: Num of Offline Users: 14000 (681.8170869350433s)
# Start: Num of Offline Users: 16000
# End: Num of Offline Users: 16000 (1416.760336637497s)
